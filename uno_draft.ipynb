# %%
from random import shuffle
from functools import reduce
from sys import stdout

class Card():
    colors = ['red', 'green', 'blue', 'yellow']
    
    def __init__(self, color):
        self.color = color
        
def card_format(card):
    value = 0
    if isinstance(card, NumberCard):
        value = card.num
    else:
        value = card.act
    
    formatted_card = "[ " + str(value) + " " + card.color + " ]"
    return formatted_card
        
class NumberCard(BaseCard):
    nums = range(10) # possible number cards
    
    def __init__(self, num, color):
        BaseCard.__init__(self, color)
        self.num = num
        
    def __str__(self):
        return card_format(self)
        
class ActionCard(BaseCard):
    actions = ['+4', '+2', 'color switch', 'reverse', 'skip']
    
    def __init__(self, act, color):
        BaseCard.__init__(self, color)
        self.act = act
        
    def __str__(self):
        return card_format(self)

class Player():
    def __init__(self, cards):
        self.cards = cards
    
    def display_cards(self):
        for idx, card in enumerate(self.cards):
            print(idx, ". ", card, sep="", end="   ")
        print("\n")
    
    def step(self, top_card):
        self.display_cards()
        
        invalid_card = True
        step = -1
        
        value_match = any(map(lambda card: card.num == top_card.num, self.cards))
        color_match = any(map(lambda card: card.color == top_card.color, self.cards))
        
        if value_match and color_match:
            while invalid_card:
                step = int(input("\rEnter the number of the card you would like to play: "))
                if 0 <= step < len(self.cards):
                    color_match = self.cards[step].color == top_card.color
                    if color_match:
                        chosen_card = self.cards[step]
                        del self.cards[step]
                        return chosen_card
                    else:
                        stdout.write("\rThis card cannot be played\n")
                else:
                    stdout.write("\rThis card does not exist\n")
                
        return step
        
        
    def sort_hand(self):
        # Logic for sorting cards in hand
        pass
    
        
class Uno():
    def __init__(self, num_players):
        self.num_players = num_players
        self.deck = self.generate_deck()
        self.players = self.distribute_cards(num_players)
        self.start()
        
    def generate_deck(self):
        deck = []
        
        for color in BaseCard.colors:
            for num in NumberCard.nums:
                deck.append(NumberCard(num, color))
            for act in ActionCard.actions:
                deck.append(ActionCard(act, color))
        shuffle(deck)
        
        return deck
    
    def distribute_cards(self, num_players):
        players = []
        
        for i in range(num_players):
            cards_to_hand = self.deck[:7] # fetch 7 cards from the top of the deck
            del self.deck[:7] # constant time card removal
            players.append(Player(cards_to_hand))
        
        return players
    
    def start(self):
        self.top_card = self.deck[0]
        del self.deck[0]
        
        turn = 0
        while reduce(lambda player_1, player_2:
                     len(player_1.cards) * len(player_2.cards), self.players):
            print("Card on top:", card_format(self.top_card))
            print("Player {0}'s turn:".format(turn))
            self.top_card = self.players[turn].step(self.top_card)
            turn = (turn + 1) % self.num_players
    
game = Uno(2)
game.players[0].display_cards()
# Out:
# Card on top: [ 6 green ]
# Player 0's turn:
# 0. [ 6 yellow ]   1. [ 8 red ]   2. [ skip red ]   3. [ 9 blue ]   4. [ 5 green ]   5. [ 3 blue ]   6. [ 9 green ]
#
# Card on top: [ 5 green ]
# Player 1's turn:
# 0. [ 9 yellow ]   1. [ 8 blue ]   2. [ 7 yellow ]   3. [ 0 yellow ]   4. [ 3 red ]   5. [ 1 green ]   6. [ +4 red ]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-e6534d946bd0> in <module>()
#     120             turn = (turn + 1) % self.num_players
#     121
# --> 122 game = Uno(2)
#     123 game.players[0].display_cards()
#
# <ipython-input-7-e6534d946bd0> in __init__(self, num_players)
#      84         self.deck = self.generate_deck()
#      85         self.players = self.distribute_cards(num_players)
# ---> 86         self.start()
#      87
#      88     def generate_deck(self):
#
# <ipython-input-7-e6534d946bd0> in start(self)
#     117             print("Card on top:", card_format(self.top_card))
#     118             print("Player {0}'s turn:".format(turn))
# --> 119             self.top_card = self.players[turn].step(self.top_card)
#     120             turn = (turn + 1) % self.num_players
#     121
#
# <ipython-input-7-e6534d946bd0> in step(self, top_card)
#      54         step = -1
#      55
# ---> 56         value_match = any(map(lambda card: card.num == top_card.num, self.cards))
#      57         color_match = any(map(lambda card: card.color == top_card.color, self.cards))
#      58
#
# <ipython-input-7-e6534d946bd0> in <lambda>(card)
#      54         step = -1
#      55
# ---> 56         value_match = any(map(lambda card: card.num == top_card.num, self.cards))
#      57         color_match = any(map(lambda card: card.color == top_card.color, self.cards))
#      58
#
# AttributeError: 'ActionCard' object has no attribute 'num'

# %%
d = queue.Queue([2, 5, 2, 5, 8, 4, 2])
print(d.get())

# %% [markdown]
# ### Notes
# 1. Add error checking
# 2. Sorting hand feature
# 3. Test suites
# 4. Winning animation
# 5. Print formatting
# 6. Multi-card stepping
# 7. Reverse
# 8. Set cards
# 9. Check if you can even play
# 10. Transfer operations
# 11. Optimize data structures

# %%
-2 % 6
# Out:
# 4

# %%
from random import shuffle
from functools import reduce
from sys import stdout

class Card():
    colors = ['red', 'green', 'blue', 'yellow']
    values = list(range(10)) + ['+4', '+2', 'color switch', 'reverse', 'skip']
    
    def __init__(self, value, color):
        self.value = value
        self.color = color
        self.isAction = isinstance(value, str)

    def __str__(self):
        return card_format(self)
        
def card_format(card):
    formatted_card = "[ " + str(card.value) + " " + card.color + " ]"
    return formatted_card
        

class Player():
    def __init__(self, cards):
        self.cards = cards
    
    def display_cards(self):
        for idx, card in enumerate(self.cards):
            print(idx, ". ", card, sep="", end="   ")
        print("\n")
    
    def step(self, top_card):
        self.display_cards()
        
        invalid_card = True
        step = -1
        
        any_value_match = any(map(lambda card: card.value == top_card.value, self.cards))
        any_color_match = any(map(lambda card: card.color == top_card.color, self.cards))
        
        if value_match and color_match:
            while invalid_card:
                step = int(input("\rEnter the number of the card you would like to play: "))
                if 0 <= step < len(self.cards):
                    
                    value_match = self.cards[step].value == top_card.value
                    color_match = self.cards[step].color == top_card.color
                    
                    if color_match:
                        chosen_card = self.cards[step]
                        del self.cards[step]
                        return chosen_card
                    else:
                        stdout.write("\rThis card cannot be played\n")
                else:
                    stdout.write("\rThis card does not exist\n")
        else:
            # handle getting a new card
            return top_card
            pass
        
    def sort_hand(self):
        # Logic for sorting cards in hand
        pass
    
        
class Uno():
    def __init__(self, num_players):
        self.num_players = num_players
        self.deck = self.generate_deck()
        self.players = self.distribute_cards(num_players)
        self.start()
        
    def generate_deck(self):
        deck = []
        
        for color in Card.colors:
            for value in Card.values:
                deck.append(Card(value, color))
        shuffle(deck)
        
        return deck
    
    def distribute_cards(self, num_players):
        players = []
        
        for i in range(num_players):
            cards_to_hand = self.deck[:7] # fetch 7 cards from the top of the deck
            del self.deck[:7] # constant time card removal
            players.append(Player(cards_to_hand))
        
        return players
    
    def start(self):
        self.top_card = self.deck[0]
        print("Hellu", self.top_card)
        del self.deck[0]
        
        turn = 0
        while reduce(lambda player_1, player_2:
                     len(player_1.cards) * len(player_2.cards), self.players):
            print("Card on top:", self.top_card)
            print("Player {0}'s turn:".format(turn % self.num_players + 1))
            self.top_card = self.players[turn].step(self.top_card)
            turn = (turn + 1) % self.num_players
    
game = Uno(2)
game.players[0].display_cards()
# Out:
# Hellu [ 8 red ]
# Card on top: [ 8 red ]
# Player 1's turn:
# 0. [ 6 blue ]   1. [ +4 blue ]   2. [ 7 red ]   3. [ color switch green ]   4. [ +2 blue ]   5. [ 5 yellow ]   6. [ 6 red ]
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-18-f6a410e5ce7c> in <module>()
#     104             turn = (turn + 1) % self.num_players
#     105
# --> 106 game = Uno(2)
#     107 game.players[0].display_cards()
#
# <ipython-input-18-f6a410e5ce7c> in __init__(self, num_players)
#      69         self.deck = self.generate_deck()
#      70         self.players = self.distribute_cards(num_players)
# ---> 71         self.start()
#      72
#      73     def generate_deck(self):
#
# <ipython-input-18-f6a410e5ce7c> in start(self)
#     101             print("Card on top:", self.top_card)
#     102             print("Player {0}'s turn:".format(turn % self.num_players + 1))
# --> 103             self.top_card = self.players[turn].step(self.top_card)
#     104             turn = (turn + 1) % self.num_players
#     105
#
# <ipython-input-18-f6a410e5ce7c> in step(self, top_card)
#      38         any_color_match = any(map(lambda card: card.color == top_card.color, self.cards))
#      39
# ---> 40         if value_match and color_match:
#      41             while invalid_card:
#      42                 step = int(input("\rEnter the number of the card you would like to play: "))
#
# UnboundLocalError: local variable 'value_match' referenced before assignment
